# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import arviz as az
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %config InlineBackend.figure_format = 'retina'
#az.style.use("arviz-darkgrid")
az.style.use("arviz-grayscale")

# %%
data = pd.read_csv('./temp.csv',sep=';', header=None)

# %%
data.head()
# Out:
#                                0       1       2       3       4       5   \
# 0              Propionylcarnitine  24.711  24.979  24.773  25.002  24.315
# 1  Inosine-5'-monophosphate (IMP)  17.858  18.332  15.491  18.252  16.121
# 2                Dilauryl citrate  15.699  15.783  15.966  15.590  15.702
# 3                     “700.52998”  15.954  15.786  16.692  18.824  16.101
# 4                       “530.057”  12.996  13.631  14.571  14.106  13.236
#
#        6       7       8       9   ...      31      32      33      34  \
# 0  24.372  24.630  24.640  24.635  ...  24.809  24.500  24.583  24.737
# 1  17.024  14.641  13.957  17.711  ...  15.219  14.094  14.578  14.839
# 2  15.583  15.417  12.660  15.171  ...  15.532  15.902  15.348  15.005
# 3  16.284  18.194  15.585  16.280  ...  17.684  16.399  15.974  18.392
# 4  14.040  13.077  13.022  14.454  ...  13.200  14.128  14.238  13.051
#
#        35      36      37      38      39      40
# ...

# %%
tmp=data.iloc[:,1:].to_numpy()
aSYN=tmp[:,:10]
comb=tmp[:,10:20]
INFg=tmp[:,20:30]
UT=tmp[:,30:]

# %%
bins=10
row1=0
row2=1
case1=np.hstack((INFg[row1],UT[row1]))
case2=np.hstack((comb[row2],UT[row2]))

# %%
sns.distplot(a=case1[:10], hist=True, color='black',hist_kws={"facecolor": 'black'}, bins=6)
sns.distplot(a=case1[10:], hist=True, color='gray', hist_kws={"facecolor": 'lightgrey'}, bins=6)
plt.title('INFg vs UT (Propionylcarnitine)')
# Out:
# /home/paavo/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/paavo/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'INFg vs UT (Propionylcarnitine)')

# %%
sns.distplot(a=case1[:10], hist=True, color='black',hist_kws={"facecolor": 'black'})
sns.distplot(a=case1[10:], hist=True, color='gray', hist_kws={"facecolor": 'lightgrey'})
plt.title('INFg vs UT (Propionylcarnitine)')
# Out:
# /home/paavo/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/paavo/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'INFg vs UT (Propionylcarnitine)')

# %%
sns.distplot(a=case2[:10], hist=True, color='black',hist_kws={"facecolor": 'black'})
sns.distplot(a=case2[10:], hist=True, color='gray', hist_kws={"facecolor": 'lightgrey'})
plt.title('comb. vs UT (Inosine monophosphate)')
# Out:
# /home/paavo/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/paavo/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'comb. vs UT (Inosine monophosphate)')

# %%
sns.distplot(a=case1[:10], hist=True)
sns.distplot(a=case2[:10], hist=True)
sns.distplot(a=case1[10:], hist=True)
sns.distplot(a=case2[10:], hist=True)
#plt.show()
plt.savefig('./FCvsMargin2.png', format='png')
# Out:
# /home/paavo/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/paavo/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
x=np.stack((case1[:20],case2[:20]))

# %%
plt.figure(figsize=(10,7))
sns.distplot(a=case2[:10], hist=True,kde=False, bins=6)
sns.distplot(a=case2[10:], hist=True,kde=False, bins=6)
sns.distplot(a=case1[:10], hist=True,kde=False, bins=6)
sns.distplot(a=case1[10:], hist=True,kde=False, bins=6)
plt.vlines([np.mean(case1[10:])],0,3)
plt.vlines([np.mean(case1[:10])],0,3,linestyles='dashed')
plt.vlines([np.mean(case2[10:])],0,3,linestyles='dashdot')
plt.vlines([np.mean(case2[:10])],0,3,linestyles='dotted')
plt.legend('LHlh')
plt.legend(['Mean UT (218.13885@1.987)', 'Mean INFg (218.13885@1.987)',\
           'Mean UT (349.0542@6.887)', 'Mean comb (349.0542@6.887)'])
#plt.legend(['Mean UT (Propionylcarnitine)', 'Mean INFg (Propionylcarnitine)',\
#           'Mean UT (Inosine)', 'Mean comb (Inosine)'])
#plt.title("Fold-change vs. Margin")
#plt.show()
plt.savefig('./FCvsMargin.png', format='png')

# %%
plt.figure(figsize=(10,7))
sns.distplot(a=case2[:10], hist=True,kde=False, hist_kws={'edgecolor': 'black'})
sns.distplot(a=case2[10:], hist=True,kde=False, hist_kws={'edgecolor': 'black'})
sns.distplot(a=case1[:10], hist=True,kde=False, hist_kws={'edgecolor': 'black'})
sns.distplot(a=case1[10:], hist=True,kde=False, hist_kws={'edgecolor': 'black'})
plt.vlines([np.mean(case1[10:])],0,5)
plt.vlines([np.mean(case1[:10])],0,5,linestyles='dashed')
plt.vlines([np.mean(case2[10:])],0,5,linestyles='dashdot')
plt.vlines([np.mean(case2[:10])],0,5,linestyles='dotted')
plt.legend('LHlh')
plt.legend(['Mean UT (218.13885@1.987)', 'Mean INFg (218.13885@1.987)',\
           'Mean UT (349.0542@6.887)', 'Mean comb (349.0542@6.887)'])
#plt.legend(['Mean UT (Propionylcarnitine)', 'Mean INFg (Propionylcarnitine)',\
#           'Mean UT (Inosine)', 'Mean comb (Inosine)'])
#plt.title("Fold-change vs. Margin")
plt.show()
#plt.savefig('./FCvsMargin.png', format='png')

# %%
plt.figure(figsize=(10,7))
sns.distplot(a=case2[:10], hist=True,kde=False, bins=np.linspace(14,26,40))
sns.distplot(a=case2[10:], hist=True,kde=False, bins=np.linspace(14,26,40))
sns.distplot(a=case1[:10], hist=True,kde=False, bins=np.linspace(14,26,40))
sns.distplot(a=case1[10:], hist=True,kde=False, bins=np.linspace(14,26,40))
plt.vlines([np.mean(case1[10:])],0,5)
plt.vlines([np.mean(case1[:10])],0,5,linestyles='dashed')
plt.vlines([np.mean(case2[10:])],0,5,linestyles='dashdot')
plt.vlines([np.mean(case2[:10])],0,5,linestyles='dotted')
plt.legend('LHlh')
plt.legend(['Mean UT (218.13885@1.987)', 'Mean INFg (218.13885@1.987)',\
           'Mean UT (349.0542@6.887)', 'Mean comb (349.0542@6.887)'])
#plt.legend(['Mean UT (Propionylcarnitine)', 'Mean INFg (Propionylcarnitine)',\
#           'Mean UT (Inosine)', 'Mean comb (Inosine)'])
#plt.title("Fold-change vs. Margin")
#plt.show()
plt.savefig('./FCvsMarginFinal.png', format='png')

# %%
plt.figure(figsize=(10,7))
sns.distplot(a=case2[:10], hist=True,kde=False, bins=5)
sns.distplot(a=case2[10:], hist=True,kde=False, bins=5)
#sns.distplot(a=case1[:10], hist=True,kde=False)
#sns.distplot(a=case1[10:], hist=True,kde=False)
#plt.vlines([np.mean(case1[10:])],0,5)
#plt.vlines([np.mean(case1[:10])],0,5,linestyles='dashed')
plt.vlines([np.mean(case2[10:])],0,5,linestyles='dashdot')
plt.vlines([np.mean(case2[:10])],0,5,linestyles='dotted')
plt.legend(['Mean UT (349.0542@6.887)', 'Mean comb (349.0542@6.887)'])
plt.xlim([14,26])
plt.show()
plt.savefig('./FCvsMarginV2.1.png', format='png')

# %%
plt.figure(figsize=(10,7))
#sns.distplot(a=case2[:10], hist=True,kde=False)
#sns.distplot(a=case2[10:], hist=True,kde=False)
sns.distplot(a=case1[:10], hist=True,kde=False, bins=5)
sns.distplot(a=case1[10:], hist=True,kde=False, bins=5)
plt.vlines([np.mean(case1[10:])],0,5)
plt.vlines([np.mean(case1[:10])],0,5,linestyles='dashed')
#plt.vlines([np.mean(case2[10:])],0,5,linestyles='dashdot')
#plt.vlines([np.mean(case2[:10])],0,5,linestyles='dotted')
plt.xlim([14,26])
plt.legend(['Mean UT (218.13885@1.987)', 'Mean INFg (218.13885@1.987)'])
#plt.legend(['Mean UT (Propionylcarnitine)', 'Mean INFg (Propionylcarnitine)',\
#           'Mean UT (Inosine)', 'Mean comb (Inosine)'])
#plt.title("Fold-change vs. Margin")
plt.show()
#plt.savefig('./FCvsMarginV2.2.png', format='png')

# %%
plt.figure()
plt.hist(case1[:10], alpha=0.2, bins=bins)
plt.hist(case1[10:], alpha=0.9, color='black', bins=bins)
plt.hist(case2[:10], alpha=0.2, bins=bins)
plt.hist(case2[10:], alpha=0.9, color='black', bins=bins)
plt.xlim(xmin=14, xmax=26)
# Out:
# (14.0, 26.0)

# %%
plt.hist(case2[:10], alpha=0.2, bins=bins)
plt.hist(case2[10:], alpha=0.9, color='black', bins=bins)
# Out:
# (array([3., 0., 1., 1., 0., 1., 1., 0., 2., 1.]),
#  array([14.05 , 14.195, 14.34 , 14.485, 14.63 , 14.775, 14.92 , 15.065,
#         15.21 , 15.355, 15.5  ]),
#  <BarContainer object of 10 artists>)
